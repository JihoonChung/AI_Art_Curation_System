# %% [markdown]
# # Web App Testing
#
# Try using `gradio`.

# %%
# Run this cell to install gradio, only if it is missing from the venv. The requirements file has been updated to reflect the changes.
#pip install gradio
# Out:
# Collecting gradio
#   Downloading gradio-4.21.0-py3-none-any.whl.metadata (15 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting altair<6.0,>=4.2.0 (from gradio)
#   Downloading altair-5.2.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting fastapi (from gradio)
#   Downloading fastapi-0.110.0-py3-none-any.whl.metadata (25 kB)
# Collecting ffmpy (from gradio)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting gradio-client==0.12.0 (from gradio)
#   Downloading gradio_client-0.12.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: httpx>=0.24.1 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from gradio) (0.27.0)
# Collecting huggingface-hub>=0.19.3 (from gradio)
#   Downloading huggingface_hub-0.21.4-py3-none-any.whl.metadata (13 kB)
# Collecting importlib-resources<7.0,>=1.3 (from gradio)
#   Downloading importlib_resources-6.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: jinja2<4.0 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from gradio) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from gradio) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from gradio) (3.8.3)
# Requirement already satisfied: numpy~=1.0 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from gradio) (1.26.4)
# Collecting orjson~=3.0 (from gradio)
#   Downloading orjson-3.9.15-cp310-none-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.7 kB ? eta -:--:--
#      ---------------------------------------- 50.7/50.7 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from gradio) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from gradio) (2.2.0)
# Requirement already satisfied: pillow<11.0,>=8.0 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from gradio) (10.2.0)
# Collecting pydantic>=2.0 (from gradio)
#   Downloading pydantic-2.6.4-py3-none-any.whl.metadata (85 kB)
#      ---------------------------------------- 0.0/85.1 kB ? eta -:--:--
#      ---------------------------------------- 85.1/85.1 kB ? eta 0:00:00
# Collecting pydub (from gradio)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from gradio) (6.0.1)
# Collecting ruff>=0.2.2 (from gradio)
#   Downloading ruff-0.3.2-py3-none-win_amd64.whl.metadata (23 kB)
# Collecting semantic-version~=2.0 (from gradio)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.9 (from typer[all]<1.0,>=0.9->gradio)
#   Downloading typer-0.9.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions~=4.0 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from gradio) (4.8.0)
# Collecting uvicorn>=0.14.0 (from gradio)
#   Downloading uvicorn-0.28.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: fsspec in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from gradio-client==0.12.0->gradio) (2023.4.0)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.12.0->gradio)
#   Downloading websockets-11.0.3-cp310-cp310-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from altair<6.0,>=4.2.0->gradio) (4.21.1)
# Collecting toolz (from altair<6.0,>=4.2.0->gradio)
#   Downloading toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: anyio in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from httpx>=0.24.1->gradio) (4.3.0)
# Requirement already satisfied: certifi in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from httpx>=0.24.1->gradio) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from httpx>=0.24.1->gradio) (1.0.4)
# Requirement already satisfied: idna in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from httpx>=0.24.1->gradio) (3.4)
# Requirement already satisfied: sniffio in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from httpx>=0.24.1->gradio) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (3.9.0)
# Collecting fsspec (from gradio-client==0.12.0->gradio)
#   Downloading fsspec-2024.2.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: requests in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Collecting tqdm>=4.42.1 (from huggingface-hub>=0.19.3->gradio)
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB ? eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from matplotlib~=3.0->gradio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from matplotlib~=3.0->gradio) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Collecting annotated-types>=0.4.0 (from pydantic>=2.0->gradio)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.16.3 (from pydantic>=2.0->gradio)
#   Downloading pydantic_core-2.16.3-cp310-none-win_amd64.whl.metadata (6.6 kB)
# Collecting click<9.0.0,>=7.1.1 (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio)
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from typer[all]<1.0,>=0.9->gradio) (0.4.6)
# Collecting shellingham<2.0.0,>=1.3.0 (from typer[all]<1.0,>=0.9->gradio)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich<14.0.0,>=10.11.0 (from typer[all]<1.0,>=0.9->gradio)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting starlette<0.37.0,>=0.36.3 (from fastapi->gradio)
#   Downloading starlette-0.36.3-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: six>=1.5 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (2.17.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from anyio->httpx>=0.24.1->gradio) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anson\documents\projects\python\ai_art_curation_system\.venv\lib\site-packages (from requests->huggingface-hub>=0.19.3->gradio) (1.26.13)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading gradio-4.21.0-py3-none-any.whl (17.0 MB)
#    ---------------------------------------- 0.0/17.0 MB ? eta -:--:--
#    -- ------------------------------------- 1.2/17.0 MB 25.5 MB/s eta 0:00:01
#    --------------- ------------------------ 6.4/17.0 MB 67.9 MB/s eta 0:00:01
#    --------------------------- ------------ 11.8/17.0 MB 108.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.8/17.0 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------- 17.0/17.0 MB 73.0 MB/s eta 0:00:00
# Downloading gradio_client-0.12.0-py3-none-any.whl (310 kB)
#    ---------------------------------------- 0.0/310.7 kB ? eta -:--:--
#    --------------------------------------- 310.7/310.7 kB 18.8 MB/s eta 0:00:00
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading altair-5.2.0-py3-none-any.whl (996 kB)
#    ---------------------------------------- 0.0/996.9 kB ? eta -:--:--
#    --------------------------------------- 996.9/996.9 kB 61.7 MB/s eta 0:00:00
# Downloading huggingface_hub-0.21.4-py3-none-any.whl (346 kB)
#    ---------------------------------------- 0.0/346.4 kB ? eta -:--:--
#    ---------------------------------------- 346.4/346.4 kB ? eta 0:00:00
# Downloading importlib_resources-6.3.0-py3-none-any.whl (35 kB)
# Downloading orjson-3.9.15-cp310-none-win_amd64.whl (136 kB)
#    ---------------------------------------- 0.0/136.0 kB ? eta -:--:--
#    ---------------------------------------- 136.0/136.0 kB ? eta 0:00:00
# Downloading pydantic-2.6.4-py3-none-any.whl (394 kB)
#    ---------------------------------------- 0.0/394.9 kB ? eta -:--:--
#    --------------------------------------- 394.9/394.9 kB 25.6 MB/s eta 0:00:00
# Downloading pydantic_core-2.16.3-cp310-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 60.4 MB/s eta 0:00:00
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading ruff-0.3.2-py3-none-win_amd64.whl (7.6 MB)
#    ---------------------------------------- 0.0/7.6 MB ? eta -:--:--
#    -------------------------- ------------- 5.0/7.6 MB 108.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.6/7.6 MB 81.9 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.9 kB ? eta -:--:--
#    ---------------------------------------- 45.9/45.9 kB 2.4 MB/s eta 0:00:00
# Downloading uvicorn-0.28.0-py3-none-any.whl (60 kB)
#    ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#    ---------------------------------------- 60.6/60.6 kB ? eta 0:00:00
# Downloading fastapi-0.110.0-py3-none-any.whl (92 kB)
#    ---------------------------------------- 0.0/92.1 kB ? eta -:--:--
#    ---------------------------------------- 92.1/92.1 kB 5.1 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ---------------------------------------- 97.9/97.9 kB 5.5 MB/s eta 0:00:00
# Downloading fsspec-2024.2.0-py3-none-any.whl (170 kB)
#    ---------------------------------------- 0.0/170.9 kB ? eta -:--:--
#    ---------------------------------------- 170.9/170.9 kB ? eta 0:00:00
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ---------------------------------------- 0.0/240.7 kB ? eta -:--:--
#    ---------------------------------------- 240.7/240.7 kB ? eta 0:00:00
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading starlette-0.36.3-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.5 kB ? eta -:--:--
#    ---------------------------------------- 71.5/71.5 kB 3.8 MB/s eta 0:00:00
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB ? eta 0:00:00
# Downloading websockets-11.0.3-cp310-cp310-win_amd64.whl (124 kB)
#    ---------------------------------------- 0.0/124.7 kB ? eta -:--:--
#    ---------------------------------------- 124.7/124.7 kB 7.2 MB/s eta 0:00:00
# Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#    ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#    ---------------------------------------- 56.1/56.1 kB ? eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#    ---------------------------------------- 87.5/87.5 kB 4.8 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (pyproject.toml): started
#   Building wheel for ffmpy (pyproject.toml): finished with status 'done'
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5607 sha256=ab79ce8f6dc80ad73c261706384051b28a053094f4beeda62bebe03a101aa6ed
#   Stored in directory: c:\users\anson\appdata\local\pip\cache\wheels\bd\65\9a\671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built ffmpy
# Installing collected packages: pydub, ffmpy, websockets, tqdm, toolz, tomlkit, shellingham, semantic-version, ruff, python-multipart, pydantic-core, orjson, mdurl, importlib-resources, fsspec, click, annotated-types, aiofiles, uvicorn, typer, starlette, pydantic, markdown-it-py, huggingface-hub, rich, gradio-client, fastapi, altair, gradio
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.4.0
#     Uninstalling fsspec-2023.4.0:
#       Successfully uninstalled fsspec-2023.4.0
# Successfully installed aiofiles-23.2.1 altair-5.2.0 annotated-types-0.6.0 click-8.1.7 fastapi-0.110.0 ffmpy-0.3.2 fsspec-2024.2.0 gradio-4.21.0 gradio-client-0.12.0 huggingface-hub-0.21.4 importlib-resources-6.3.0 markdown-it-py-3.0.0 mdurl-0.1.2 orjson-3.9.15 pydantic-2.6.4 pydantic-core-2.16.3 pydub-0.25.1 python-multipart-0.0.9 rich-13.7.1 ruff-0.3.2 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.36.3 tomlkit-0.12.0 toolz-0.12.1 tqdm-4.66.2 typer-0.9.0 uvicorn-0.28.0 websockets-11.0.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Workflow
# **Inputs**
# 1. Allow user to upload image of artwork.
# 2. Allow user to select if segmentation will be applied (`True`,`False`)
# 3. Allow user to select region of interest by cropping (Need to decide if automatically prompts)
# 4. Flagging?
#
# **Internal**
#
# 1. Process user image to fit input required by model (zero-padding resize to 224x224 with optional segmentation into 3x3 grid)
# 2. Input to model (maybe allow model selection in the future?)
# 3. Outputs: Style Class, Genre Class, Caption, (Image)
#
# **Output**
#
# 1. Display outputs
# 2. Allow for feedback

# %% [markdown]
# ## Basic Webapp
# Test app with basic functionality and integrations.

# %%
import gradio as gr
from PIL import Image
import torch
import torch.nn as nn
from torchvision import transforms

# Define a random model for testing purposes
class RandomModel(nn.Module):
    def __init__(self, num_classes):
        super(RandomModel, self).__init__()
        self.num_classes = num_classes
        self.fc = nn.Linear(224 * 224 * 3, num_classes)  # Assuming input size is 224x224 and 3 channels

    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

# Define a list of genre labels for testing purposes
classes = ['Realism', 'Baroque', 'Post_Impressionism', 'Impressionism',
       'Romanticism', 'Art_Nouveau', 'Northern_Renaissance', 'Symbolism',
       'Naive_Art_Primitivism', 'Expressionism', 'Cubism', 'Fauvism',
       'Analytical_Cubism', 'Abstract_Expressionism', 'Synthetic_Cubism',
       'Pointillism', 'Early_Renaissance', 'Color_Field_Painting',
       'New_Realism', 'Ukiyo_e', 'Rococo', 'High_Renaissance',
       'Mannerism_Late_Renaissance', 'Pop_Art', 'Contemporary_Realism',
       'Minimalism', 'Action_painting']

# Define the custom function to preprocess the image and get predictions
def preprocess_image(image):
    # Open image using PIL
    # Add zero padding to make the aspect ratio 1:1
    width, height = image.size
    max_dim = max(width, height)
    new_size = (max_dim, max_dim)
    padded_image = Image.new("RGB", new_size)
    padded_image.paste(image, ((max_dim - width) // 2, (max_dim - height) // 2))

    # Resize the image to 224x224
    resized_image = padded_image.resize((224, 224))

    # Convert PIL image to PyTorch tensor
    preprocess = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    input_tensor = preprocess(resized_image).unsqueeze(0)

    return input_tensor

def predict_genre(image):
    # Preprocess the image
    input_tensor = preprocess_image(image['layers'][0])

    # Initialize the random model
    model = RandomModel(num_classes=len(classes))

    # Get prediction from model
    with torch.no_grad():
        model.eval()
        outputs = model(input_tensor)
        _, predicted = torch.max(outputs, 1)
        genre = classes[predicted.item()]

    return genre

# Define the Gradio interface
input_image = gr.ImageEditor(type='pil', image_mode='RGB', transforms='crop', eraser=False, brush=False)
output_genre = gr.Textbox()

test = gr.Interface(fn=predict_genre, inputs=input_image, outputs=output_genre, title='Art Style Prediction', 
             description='Upload an image (and select a region of interest)',allow_flagging='never')
test.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7867
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7867/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # TODO

# %% [markdown]
# Add custom blocks:
# - Inputs
#     - Segmentation Button/Checkbox (True/False)
#     - Select Model?
# - Outputs
#     - Style Labels (sorted by highest likelihood)
#     - Genre Labels (sorted by highest likelihood)
#     - Caption
#     - Display Image
# - Feedback
#     - Flagging (should this new image be added to improve model)
#     - Satistifaction (quality of caption)
#     - Corrections (allow users to submit correct class if wrong)
